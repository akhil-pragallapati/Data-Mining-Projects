# %% [markdown]
# # Rating prediction on YELP Dataset

# %% [markdown]
# **Author : Akhil Pragallapati**

# %% [markdown]
# Please download the Yelp dataset from the below links
#
# yelp_academic_dataset_business.json : https://1drv.ms/u/s!AiGIl5xHfZC9-T-rj5YWoG4nN_uP?e=D558Nn
#
# yelp_academic_dataset_checkin.json : https://1drv.ms/u/s!AiGIl5xHfZC9-Tvr0Mb93uqdQhKt?e=hDiEkW
#
# **Here is an example of the data format:**
# ### Business Objects
#
# Business objects contain basic information about local businesses. The fields are as follows:
#
# ```json
# {
#   'type': 'business',
#   'business_id': (a unique identifier for this business),
#   'name': (the full business name),
#   'neighborhoods': (a list of neighborhood names, might be empty),
#   'full_address': (localized address),
#   'city': (city),
#   'state': (state),
#   'latitude': (latitude),
#   'longitude': (longitude),
#   'stars': (star rating, rounded to half-stars),
#   'review_count': (review count),
#   'photo_url': (photo url),
#   'categories': [(localized category names)]
#   'open': (is the business still open for business?),
#   'schools': (nearby universities),
#   'url': (yelp url)
# }
# ```
# ### Checkin Objects
# ```json
# {
#     'type': 'checkin',
#     'business_id': (encrypted business id),
#     'checkin_info': {
#         '0-0': (number of checkins from 00:00 to 01:00 on all Sundays),
#         '1-0': (number of checkins from 01:00 to 02:00 on all Sundays),
#         ...
#         '14-4': (number of checkins from 14:00 to 15:00 on all Thursdays),
#         ...
#         '23-6': (number of checkins from 23:00 to 00:00 on all Saturdays)
#     }, # if there was no checkin for a hour-day block it will not be in the dict
# }
# ```

# %% [markdown]
# # Problem statement:
#
# The goal of this project is to build a model that can accurately predict the star rating of a business, given its other attributes.
# The reason why this problem statement is important are
#
# 1) Companies which have high star ratings will be attracting more clients than those with lower ratings. This can then help businesses by expanding their client base and gaining more profit.
#
# 2)An accurate star rating predictions can assist business owners in identifying areas for development and in taking steps to raise their overall rating. Based on the predictors we use the business owners can find out the business areas which needs to be concentrated.
#
# 3)This problem description is crucial since it offers a specific and quantifiable criterion for assessing firms.

# %% [markdown]
# # Data Collection/Processing:

# %%
import json
import pandas as pd
business_json_path = 'yelp_academic_dataset_business.json'
df = pd.read_json(business_json_path, lines=True)


# Here We are creating an extra column to the database which helps to predict the star score better.
attScore = []
for i in df['attributes']:
    s = 0
    if i != None:
        for k,v in i.items():
            if v == "True":
                s = s + 1
    attScore = attScore + [s] 
df['Attribute_Score'] = attScore

# %%
df
# Out:
#                    business_id                             name  \
# 0       Apn5Q_b6Nz61Tq4XzPdf9A             Minhas Micro Brewery
# 1       AjEbIBw6ZFfln7ePHha9PA              CK'S BBQ & Catering
# 2       O8S5hYJ1SMc8fA4QBtVujA                    La Bastringue
# 3       bFzdJJ3wp3PZssNEsyU23g                  Geico Insurance
# 4       8USyCYqpScwiNEb58Bt6CA                    Action Engine
# ...                        ...                              ...
# 188588  sMQAZ3DkfrURFoJAyOhjEw                     Ross Massage
# 188589  6hvuCibNS4uECetHb9MCQQ            Four Seasons Boutique
# 188590  KleCXFYOmdACcQUvf6_XEg              Walmart Supercenter
# 188591  3_fIsSxN2RBovQ_6EFtLzA  Residence Inn Charlotte Concord
# 188592  NkOvIueadjFUxeCyq_uQEw     Tito Jimy Salon and Boutique
#
#                      neighborhood                    address        city  \
# 0                                          1314 44 Avenue NE     Calgary
# 1                                                              Henderson
# 2       Rosemont-La Petite-Patrie        1335 rue Beaubien E    Montréal
# 3                                            211 W Monroe St     Phoenix
# 4                                        2005 Alyth Place SE     Calgary
# ...                           ...                        ...         ...
# 188588                             8000 McKnight Rd, Ste 570  Pittsburgh
# 188589                                     3341 Babcock Blvd  Pittsburgh
# 188590                                       5825 Thunder Rd     Concord
# 188591                               7601 Scott Padgett Pkwy     Concord
# 188592                   Eastside    3900 Paradise Rd, Ste R   Las Vegas
#
#        state postal_code   latitude   longitude  stars  review_count  is_open  \
# 0         AB     T2E 6L6  51.091813 -114.031675    4.0            24        1
# 1         NV       89002  35.960734 -114.939821    4.5             3        0
# 2         QC     H2G 1K7  45.540503  -73.599300    4.0             5        0
# 3         AZ       85003  33.449999 -112.076979    1.5             8        1
# 4         AB     T2H 0N5  51.035591 -114.027366    2.0             4        1
# ...      ...         ...        ...         ...    ...           ...      ...
# 188588    PA       15237  40.551152  -80.021213    2.5             9        0
# 188589    PA       15237  40.534242  -80.019556    2.0             5        1
# 188590    NC       28027  35.378669  -80.724733    3.0            26        1
# 188591    NC       28027  35.364366  -80.703454    4.0            19        1
# 188592    NV       89169  36.118697 -115.154269    4.0             8        1
#
#                                                attributes  \
# 0       {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1       {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2       {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 3                                                    None
# 4                  {'BusinessAcceptsCreditCards': 'True'}
# ...                                                   ...
# 188588  {'AcceptsInsurance': 'False', 'BusinessAccepts...
# 188589                                               None
# 188590  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 188591  {'BusinessAcceptsCreditCards': 'True', 'DogsAl...
# 188592  {'BikeParking': 'True', 'BusinessAcceptsCredit...
#
#                                                categories  \
# 0       Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1       Chicken Wings, Burgers, Caterers, Street Vendo...
# 2       Breakfast & Brunch, Restaurants, French, Sandw...
# 3                           Insurance, Financial Services
# 4       Home & Garden, Nurseries & Gardening, Shopping...
# ...                                                   ...
# 188588        Skin Care, Beauty & Spas, Day Spas, Massage
# 188589  Fashion, Women's Clothing, Accessories, Bridal...
# 188590  Mobile Phones, Shopping, Department Stores, Fo...
# 188591  Event Planning & Services, Hotels & Travel, Ho...
# 188592  Makeup Artists, Men's Clothing, Swimwear, Shop...
#
#                                                     hours  Attribute_Score
# 0       {'Monday': '8:30-17:0', 'Tuesday': '11:0-21:0'...                6
# 1       {'Friday': '17:0-23:0', 'Saturday': '17:0-23:0...                8
# 2       {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...                6
# 3                                                    None                0
# 4       {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...                1
# ...                                                   ...              ...
# 188588  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...                1
# 188589                                               None                0
# 188590  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...                3
# 188591  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...                2
# 188592  {'Tuesday': '11:0-19:0', 'Wednesday': '11:0-19...                4
#
# [188593 rows x 16 columns]

# %%
# Displaying the total length of the dataset
print(len(df))


#Removing the Null Values as part of the data preprocessig step.
df = df.dropna()

# Again displaying the values after the null values are removed.
print(len(df))
# Out:
# 188593
# 127442

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# this step is performed to normalize the dataset we have for better results.

# creating the MinMaxScaler object
scaler = MinMaxScaler()

# selecting only the columns which we will be using to normalize
columns_to_normalize = ['latitude', 'longitude', 'review_count','Attribute_Score' ]

# normalize the selected columns
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])
# Out:
# C:\Users\praga\AppData\Local\Temp\ipykernel_4024\821395223.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])

# %%
df
# Out:
#                    business_id                             name  \
# 0       Apn5Q_b6Nz61Tq4XzPdf9A             Minhas Micro Brewery
# 1       AjEbIBw6ZFfln7ePHha9PA              CK'S BBQ & Catering
# 2       O8S5hYJ1SMc8fA4QBtVujA                    La Bastringue
# 4       8USyCYqpScwiNEb58Bt6CA                    Action Engine
# 5       45bWSZtniwPRiqlivpS8Og       The Coffee Bean & Tea Leaf
# ...                        ...                              ...
# 188585  Y_7sZoSLTJ-2mNZS8JS5Pg               Toronto Yoga Mamas
# 188588  sMQAZ3DkfrURFoJAyOhjEw                     Ross Massage
# 188590  KleCXFYOmdACcQUvf6_XEg              Walmart Supercenter
# 188591  3_fIsSxN2RBovQ_6EFtLzA  Residence Inn Charlotte Concord
# 188592  NkOvIueadjFUxeCyq_uQEw     Tito Jimy Salon and Boutique
#
#                      neighborhood                          address  \
# 0                                                1314 44 Avenue NE
# 1
# 2       Rosemont-La Petite-Patrie              1335 rue Beaubien E
# 4                                              2005 Alyth Place SE
# 5                                  20235 N Cave Creek Rd, Ste 1115
# ...                           ...                              ...
# 188585                Leslieville     1402 Queen Street E, Suite D
# 188588                                   8000 McKnight Rd, Ste 570
# 188590                                             5825 Thunder Rd
# 188591                                     7601 Scott Padgett Pkwy
# 188592                   Eastside          3900 Paradise Rd, Ste R
#
#               city state postal_code  latitude  longitude  stars  \
# 0          Calgary    AB     T2E 6L6  0.783430   0.223556    4.0
# 1        Henderson    NV       89002  0.686934   0.220478    4.5
# 2         Montréal    QC     H2G 1K7  0.748027   0.360574    4.0
# 4          Calgary    AB     T2H 0N5  0.783071   0.223570    2.0
# 5          Phoenix    AZ       85024  0.672334   0.230339    4.0
# ...            ...   ...         ...       ...        ...    ...
# 188585     Toronto    ON     M4L 1C9  0.736065   0.341173    5.0
# 188588  Pittsburgh    PA       15237  0.716208   0.338811    2.5
# 188590     Concord    NC       28027  0.683222   0.336427    3.0
# 188591     Concord    NC       28027  0.683130   0.336499    4.0
# 188592   Las Vegas    NV       89169  0.687941   0.219751    4.0
#
#         review_count  is_open  \
# 0           0.002637        1
# 1           0.000000        0
# 2           0.000251        0
# 4           0.000126        1
# 5           0.007533        1
# ...              ...      ...
# 188585      0.001381        1
# 188588      0.000753        0
# 188590      0.002888        1
# 188591      0.002009        1
# 188592      0.000628        1
#
#                                                attributes  \
# 0       {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1       {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2       {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 4                  {'BusinessAcceptsCreditCards': 'True'}
# 5       {'BikeParking': 'True', 'BusinessAcceptsCredit...
# ...                                                   ...
# 188585  {'BikeParking': 'True', 'BusinessParking': '{'...
# 188588  {'AcceptsInsurance': 'False', 'BusinessAccepts...
# 188590  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 188591  {'BusinessAcceptsCreditCards': 'True', 'DogsAl...
# 188592  {'BikeParking': 'True', 'BusinessAcceptsCredit...
#
#                                                categories  \
# 0       Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1       Chicken Wings, Burgers, Caterers, Street Vendo...
# 2       Breakfast & Brunch, Restaurants, French, Sandw...
# 4       Home & Garden, Nurseries & Gardening, Shopping...
# 5                                      Coffee & Tea, Food
# ...                                                   ...
# 188585  Massage, Health & Medical, Yoga, Doulas, Activ...
# 188588        Skin Care, Beauty & Spas, Day Spas, Massage
# 188590  Mobile Phones, Shopping, Department Stores, Fo...
# 188591  Event Planning & Services, Hotels & Travel, Ho...
# 188592  Makeup Artists, Men's Clothing, Swimwear, Shop...
#
#                                                     hours  Attribute_Score
# 0       {'Monday': '8:30-17:0', 'Tuesday': '11:0-21:0'...         0.400000
# 1       {'Friday': '17:0-23:0', 'Saturday': '17:0-23:0...         0.533333
# 2       {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...         0.400000
# 4       {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...         0.066667
# 5       {'Monday': '5:30-20:0', 'Tuesday': '5:30-20:0'...         0.333333
# ...                                                   ...              ...
# 188585  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...         0.200000
# 188588  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...         0.066667
# 188590  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...         0.200000
# 188591  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...         0.133333
# 188592  {'Tuesday': '11:0-19:0', 'Wednesday': '11:0-19...         0.266667
#
# [127442 rows x 16 columns]

# %% [markdown]
# # Data Exploration: Exploring the Yelp Dataset
#
# **(1) Finding the most popular business categories:**

# %%
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary
from collections import Counter
from prettytable import PrettyTable


c = ""
for j in df['categories']:
    if j != None:
        c = c + j
categories = c.split(",")

counts = Counter(categories)
a = list(counts.most_common(10))

xa = PrettyTable()

xa.field_names = ["S.No","Business Category", "count"]


for i in range(10):
    #print(bussiness_id[i], checkins[i])
    xa.add_row([i+1,a[i][0], a[i][1]])
print(xa)
# Out:
# +------+----------------------------+-------+
# | S.No |     Business Category      | count |
# +------+----------------------------+-------+
# |  1   |         Restaurants        | 17966 |
# |  2   |          Shopping          | 12322 |
# |  3   |            Food            |  9931 |
# |  4   |        Home Services       |  6528 |
# |  5   |        Beauty & Spas       |  6495 |
# |  6   |      Health & Medical      |  6283 |
# |  7   |          Nightlife         |  6091 |
# |  8   |            Bars            |  5602 |
# |  9   |       Local Services       |  5227 |
# |  10  |  Event Planning & Services |  4247 |
# +------+----------------------------+-------+

# %% [markdown]
# **(2) Find the most popular business objects**

# %%
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary

import json
import pandas as pd
business_json_path = 'yelp_academic_dataset_checkin.json'
dfc = pd.read_json(business_json_path, lines=True)

# %%
pop = dict()
for i in range(len(dfc)):
    totalCheck = 0
    for j in dfc['checkin_info'][i].values():
        #print(j)
        totalCheck = totalCheck + j
    pop[dfc['business_id'][i]] =  totalCheck

# %%
from prettytable import PrettyTable

x = PrettyTable()

x.field_names = ["S.No","Business ID", "Checkins"]
# sort the dictionary by values
sorted_dict = dict(sorted(pop.items(), key=lambda item: item[1], reverse=True))
#print(len(dfc))
#print(len(pop))
# print the sorted dictionary
#print(sorted_dict)
#print(len(sorted_dict))

checkins = list(sorted_dict.values())

bussiness_id = list(sorted_dict.keys())

#print(bussiness_id[:10])
#print(checkins[:10])

for i in range(10):
    #print(bussiness_id[i], checkins[i])
    x.add_row([i+1,bussiness_id[i], checkins[i]])
print(x)
# Out:
# +------+------------------------+----------+
# | S.No |      Business ID       | Checkins |
# +------+------------------------+----------+
# |  1   | jf67Z1pnwElRSXllpQHiJg |  77320   |
# |  2   | hW0Ne_HTHEAgGF1rAdmR-g |  68711   |
# |  3   | 3Q0QQPnHcJuX1DLCL9G9Cg |  29893   |
# |  4   | AtjsjFzalWqJ7S9DUFQ4bw |  27356   |
# |  5   | JpHE7yhMS5ehA9e8WG_ETg |  18208   |
# |  6   | 34uJtlPnKicSaX1V8_tu1A |  18099   |
# |  7   | eWPFXL1Bmu1ImtIa2Rqliw |  17671   |
# |  8   | -7yF42k0CcJhtPw51oaOqQ |  17419   |
# |  9   | z3SyT8blMIhsZNvKJgKcRA |  17161   |
# |  10  | 2e2e7WgqU1BnpxmQL5jbfw |  16641   |
# +------+------------------------+----------+

# %% [markdown]
# **(3) Other explorations are:**

# %%
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary

# Writing a code to show the top 5 Categories with highest rating and lowest ratings

import pandas as pd
import matplotlib.pyplot as plt

business_json_path = 'yelp_academic_dataset_business.json'
yelp_data = pd.read_json(business_json_path, lines=True)

# Select the columns we need
review_data = yelp_data[['business_id', 'stars', 'categories']]

# Calculating the average star rating for each category
category_average_ratings = review_data.groupby('categories', as_index=False)['stars'].mean()
category_average_ratings = category_average_ratings.sort_values(by='stars', ascending=False)

print("Top 5 Categories with the Highest Average Star Rating")
print(category_average_ratings.head(5))

r = range(1,6)

# Ploting the top 5 categories with the highest average star rating
fig, ax = plt.subplots(figsize=(12, 6))
top_categories = category_average_ratings.head(5)

ax.bar(top_categories['categories'], top_categories['stars'])
ax.set_xlabel('Category')
ax.set_ylabel('Average Star Rating')
ax.set_xticks(r)
ax.set_title('Top 5 Categories with the Highest Average Star Rating')
plt.show()


print("Top 5 Categories with the Highest Average Star Rating")
print(category_average_ratings.tail(5))

# Ploting the top 5 categories with the lowest average star rating
fig, ax = plt.subplots(figsize=(12, 6))
bottom_categories = category_average_ratings.tail(5)
ax.bar(bottom_categories['categories'], bottom_categories['stars'])

ax.set_xlabel('Category')
ax.set_ylabel('Average Star Rating')

ax.set_xticks(r)
ax.set_title('Top 5 Categories with the Lowest Average Star Rating')
plt.show()
# Out:
# Top 5 Categories with the Highest Average Star Rating
#                                               categories  stars
# 0      3D Printing, Local Services, Shopping, Customi...    5.0
# 38495  Health & Medical, Beauty & Spas, Medical Spas,...    5.0
# 38516  Health & Medical, Beauty & Spas, Reflexology, ...    5.0
# 38515  Health & Medical, Beauty & Spas, Reflexology, ...    5.0
# 38512  Health & Medical, Beauty & Spas, Physical Ther...    5.0
# Top 5 Categories with the Highest Average Star Rating
#                                               categories  stars
# 81743  Travel Services, Hotels & Travel, Banks & Cred...    1.0
# 62037  Professional Services, Arts & Entertainment, E...    1.0
# 81740  Travel Services, Event Planning & Services, Re...    1.0
# 62026  Professional Services, Air Duct Cleaning, Loca...    1.0
# 53715  Motorcycle Dealers, Automotive, Motorcycle Rep...    1.0

# %% [markdown]
# # Solution :
#
# We have a dataset that contains information about businesses, including their category, location, and review count. Our target variable is the "stars" column, which ranges from 1 to 5 (in half-star increments).
# The dataset includes both numerical and categorical variables, which will require different preprocessing techniques. We will need to handle missing data, outliers, and categorical variables with a large number of unique values.
# The success of this project could benefit both consumers and business owners. Consumers can use this model to find businesses that are likely to meet their expectations, while business owners can use it to identify areas for improvement and increase their overall rating.
#
# I have used 3 Machine learning models to predict the star rating of the business
# 1.Multiple Linear regression
# 2. Random Forest Regressor
# 3. KNN

# %% [markdown]
# Code to implement the solution in python:

# %%
# Code to implement the Multiple Linear Regression Model

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Selecting the features we want to use for prediction
features = ['latitude', 'longitude', 'review_count', 'Attribute_Score']

# Extracting the features and target variable from the dataframe
X = df[features] # predictors
y = df['stars']  # Target

# Splitting the data into training and testing sets with 25% 75% split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Create a linear regression model and fit it to the training data
model = LinearRegression()
model.fit(X_train, y_train)

# Predict the star rating for the testing data
y_pred_linear = model.predict(X_test)

# Calculate the mean squared error (MSE) of the predictions
mse = mean_squared_error(y_test, y_pred_linear)

mse_linear = mse
y_test_linear = y_test

print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 0.8602289342514422

# %%
# Code to implement the RandomForestRegressor

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error



# Selecting relevant features
features = ['latitude', 'longitude', 'review_count', 'Attribute_Score']

# Convert categorical features to numerical
#data = pd.get_dummies(data, columns=['attributes'])#, 'BusinessAcceptsCreditCards', 'NoiseLevel', 'OutdoorSeating', 'RestaurantsAttire', 'RestaurantsDelivery', 'RestaurantsReservations', 'RestaurantsTakeOut'])


# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df['stars'], test_size=0.2, random_state=42)

# Train a random forest regression model
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# Predict on the test set
y_pred = rf.predict(X_test)

# Evaluate the model using mean squared error
mse = mean_squared_error(y_test, y_pred)
print('Mean squared error: {:.2f}'.format(mse))

mse_forest = mse

y_pred_forest = y_pred
y_test_forest = y_test
# Out:
# Mean squared error: 0.87

# %%
# Code to implement the K Nearest Neighbours

import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

def knn(k):
    # defining the relevant features for predicting the rating
    X = df[['review_count', 'latitude', 'longitude', 'Attribute_Score']]
    y = df['stars']

    # Splitting the dataset into training and testing sets 30% and 70%
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Train the KNN model
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train, y_train)

    # Predict the ratings for the test set
    y_pred = knn.predict(X_test)

    # Evaluate the performance of the model using Mean Squared Error and R2 Score
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    #print("Mean Squared Error:", mse)
    
    return mse

# %%
mknn = []
kvalues= [5,10,16,19,25,30,41,56,77,89,100,150, 170, 200, 250]
for i in kvalues:
    ab = knn(i)
    mknn = mknn + [ab]
#print(mknn)


import matplotlib.pyplot as plt
plt.figure(figsize=(25,10))
plt.plot(kvalues, mknn,color = 'red')

plt.title("MSE analysis based on K values ",fontdict={'fontsize': 20})
plt.xlabel('K Values',fontdict={'fontsize': 15})
plt.ylabel('MSE Values',fontdict={'fontsize': 15})
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Code to implement the K Nearest Neighbours

#based on the graph above selecting the k valye as 75

import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


# defining the relevant features for predicting the rating
X = df[['review_count', 'latitude', 'longitude', 'Attribute_Score']]
y = df['stars']

# Splitting the dataset into training and testing sets 30% and 70%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train the KNN model
knn = KNeighborsRegressor(n_neighbors=70)
knn.fit(X_train, y_train)

# Predict the ratings for the test set
y_pred = knn.predict(X_test)

# Evaluate the performance of the model using Mean Squared Error and R2 Score
mse = mean_squared_error(y_test, y_pred)

print("Mean Squared Error:", mse)


mse_knn = mse
y_pred_knn = y_pred
y_test_knn = y_test
# Out:
# Mean Squared Error: 0.8281030558065824

# %% [markdown]
# # Results:

# %%
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary

# Code to disply the plots between various Models predicted results and the original dataset values.

#I have limited the plot to 100 rows as, the entire dataset is huge and not be visually clear if diaplayed.

import matplotlib.pyplot as plt
plt.figure(figsize=(25,10))
plt.plot(range(100), y_pred_linear[:100],color = 'red', label='Predicted')
plt.plot(range(100), y_test_linear[:100],color = 'blue', label='Original')
plt.title("Linear Regression Model",fontdict={'fontsize': 20})
plt.xlabel('Businesses',fontdict={'fontsize': 15})
plt.ylabel('Rating',fontdict={'fontsize': 15})
plt.legend()
plt.show()


plt.figure(figsize=(25,10))
plt.plot(range(100), y_pred_forest[:100],color = 'red', label='Predicted')
plt.plot(range(100), y_test_forest[:100],color = 'blue', label='Original')
plt.title("Random Forest Regressor",fontdict={'fontsize': 20})
plt.xlabel('Businesses',fontdict={'fontsize': 15})
plt.ylabel('Rating',fontdict={'fontsize': 15})
plt.legend()
plt.show()



plt.figure(figsize=(25,10))
plt.plot(range(100), y_pred_knn[:100],color = 'red', label='Predicted')
plt.plot(range(100), y_test_knn[:100],color = 'blue', label='Original')
plt.title("K Nearest Neighbors",fontdict={'fontsize': 20})
plt.xlabel('Businesses',fontdict={'fontsize': 15})
plt.ylabel('Rating',fontdict={'fontsize': 15})
plt.legend()
plt.show()

# %%
from prettytable import PrettyTable

x = PrettyTable()

x.field_names = ["S.No","Machine Learning Model", "MSE"]
x.add_row([1,"Linear Regression", mse_linear])
x.add_row([2,"Rnadom Forest Regressor", mse_forest])
x.add_row([3,"K Nearest Neighbors", mse_knn])

print(x)
# Out:
# +------+-------------------------+--------------------+
# | S.No |  Machine Learning Model |        MSE         |
# +------+-------------------------+--------------------+
# |  1   |    Linear Regression    | 0.8602289342514422 |
# |  2   | Rnadom Forest Regressor | 0.8684561753703639 |
# |  3   |   K Nearest Neighbors   | 0.8281030558065824 |
# +------+-------------------------+--------------------+

# %% [markdown]
# # Conclusion:
#
# In order to summarize based on the Mean Square Erros in the above table, we can say that "linear regression" model might be a good fit for analysis.But if we obseve the plots above we can say that Linear regression line is mostly giving us the average values due to which error is less, this should not be the ideal model.
# If we observe the "K Nearest Neighbors" the graph, the graph tends to follow the original values to a much better manner. And as the error value from the MSE is also compratively good.
# We can conclude that using "K Nearest Neighbors" would be a good decision to predict the future values of the star ratings.
